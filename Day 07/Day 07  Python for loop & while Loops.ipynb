# %%
name = "i am ridoy"

for new in name:
    print(new)
# Out:
# i
#
# a
# m
#
# r
# i
# d
# o
# y

# %%
num = "123456789"

for i in num:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
number = "123456"

for i in number:
    print(number)
# Out:
# 123456
# 123456
# 123456
# 123456
# 123456
# 123456

# %%
a = "123456789"

for i in a:
    print("ridoy")
# Out:
# ridoy
# ridoy
# ridoy
# ridoy
# ridoy
# ridoy
# ridoy
# ridoy
# ridoy

# %%
#Len Function creating for loop
a = "i love codin, i am learning python from inception bd"

# %%
len(a)
# Out:
# 52

# %%
b = 0
for i in a:
    b = b+1
print(b)
# Out:
# 52

# %%
# WHILE fUNCTION

b = 0
while b < 5:
    b = b+1
    print(b)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# vag kora python e 

a = 15
a = a%2
print(a)
# Out:
# 1

# %%
# jor sonkha print

a = 0
while a < 5:
    a = a+1
    if a%2 ==0:
        print(a)
# Out:
# 2
# 4

# %%
# bejor sonkha print

a = 0
while a < 5:
    a = a+1
    if a%2 != 0:
        print(a)
# Out:
# 1
# 3
# 5

# %%
# for loop range Function

a = "my name is ridoy"
for i in range(3):
    print("ridoy")
# Out:
# ridoy
# ridoy
# ridoy

# %%
# for loop creating count function

name = "inception"
name.count("i")
# Out:
# 2

# %%
result = 0
for n in name:
    if n == "i":
        result = result + 1
print(result)
# Out:
# 2

# %%
# break function for loop

a = "hi my name is ridoy"

for i in a:
    print(i)
    if i == "r":
        break
# Out:
# h
# i
#
# m
# y
#
# n
# a
# m
# e
#
# i
# s
#
# r
