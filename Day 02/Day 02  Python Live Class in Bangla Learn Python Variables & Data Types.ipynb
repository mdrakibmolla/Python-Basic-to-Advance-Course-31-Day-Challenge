# %%
a = 20

# %%
_ame = 20

# %%
name = 20

# %%
a = 90
A = 100

# %%
a
# Out:
# 90

# %%
A
# Out:
# 100

# %%
num = 10
NUM = 20

# %%
num
# Out:
# 10

# %%
NUM
# Out:
# 20

# %%
num1 = 10
num2 = 11
num3 = 12

# %%
id(num1)
# Out:
# 140736806368456

# %%
id(num2)
# Out:
# 140736806368488

# %%
id(num3)
# Out:
# 140736806368520

# %%
num1 = 10

# %%
num1
# Out:
# 10

# %%
type(num1)
# Out:
# int

# %%
num2 = 10.1

# %%
num2
# Out:
# 10.1

# %%
type(num2)
# Out:
# float

# %%
num3 = 20+4j

# %%
type(num3)
# Out:
# complex

# %%
a = 11
b = 11.1

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float
