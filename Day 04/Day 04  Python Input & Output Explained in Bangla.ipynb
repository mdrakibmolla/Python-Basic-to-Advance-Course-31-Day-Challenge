# %%
v = 50

# %%
v = 50

# %%
v
# Out:
# 50

# %%
num = 40
num1 = 60
num + num1
# Out:
# 100

# %%
num = input()
# Out:
#  90

# %%
num
# Out:
# '90'

# %%
a = input("Enter Your First Name: ")
b = input("Enter Your Last Name: ")
# Out:
# Enter Your First Name:  md ridoy
# Enter Your Last Name:  hossain

# %%
a
# Out:
# 'md ridoy'

# %%
b
# Out:
# 'hossain'

# %%
m_number = input("inter your mobline number: ")
# Out:
# inter your mobline number:  02929992929

# %%
m_number
# Out:
# '02929992929'

# %%
first_name = input("First Name: ")
last_name = input("Last Name: ")
mobile_number = input("Mobile Number: ")
# Out:
# First Name:  Rakib
# Last Name:  Mollah
# Mobile Number:  102939838383

# %%
first_name
# Out:
# 'Rakib'

# %%
#input ke casting korlam int and float diye

# %%
num1 = int(input("enter first number: "))
num2 = int(input("enter secound number: "))
num1 + num2
# Out:
# enter first number:  30
# enter secound number:  20
# 50

# %%
a = "500"
a = int(a)

# %%
a
# Out:
# 500

# %%
num1 = float(input("enter first number: "))
num2 = float(input("enter secound number: "))
num1 + num2
# Out:
# enter first number:  20.2
# enter secound number:  43.43
# 63.629999999999995

# %%
#print function topic

# %%
print("Md rakibh Molla")
# Out:
# Md rakibh Molla

# %%
a = (10,20,30,40)

# %%
print("i am learing python Programmer")
# Out:
# i am learing python Programmer

# %%
# object-value(s) to be pronted

# %%
print("iception", "python", "Live Class", )
# Out:
# iception python Live Class

# %%
print("i", "Love", "Coding", sep = "❤️")
# Out:
# i❤️Love❤️Coding

# %%
print("i", "Love", "Coding", sep = " ")
# Out:
# i Love Coding

# %%
print("my name is ridoy", end = " xx ")
print("i Love Coding")
# Out:
# my name is ridoy xx i Love Coding

# %%
print("my name is ridoy", end = " ")
print("i Love Coding")
# Out:
# my name is ridoy i Love Coding

# %%
print("hi i am a\t programmer")
# Out:
# hi i am a	 programmer

# %%
print("hi i am a\n programmer person")
# Out:
# hi i am a
#  programmer person

# %%
# flush (optional) - boolean specifying if the output is flushed or Default: False
a = "i am programmer"

# %%
print(a)
# Out:
# i am programmer

# %%
b = 50

# %%
print(b)
# Out:
# 50

# %%
#print (var + 'pass')
b = 50
print(b, "it is a possitive number")
# Out:
# 50 it is a possitive number

# %%
print(b, 100)
# Out:
# 50 100

# %%
# 2 var prined one Print Function
a = 50
b = "coding"
print(a,b)
# Out:
# 50 coding

# %%
num1 = float(input("enter first number: "))
num2 = float(input("enter secound number: "))
result = num1 + num2
print(result)
# Out:
# enter first number:  20
# enter secound number:  21
# 41.0

# %%
# print(f'The Value of var1 is {var1} and var2 is {var2}')
print("Thank you for using my app")
num1 = float(input("please enter a number: "))
num2 = float(input("please enter another number: "))
result = num1 + num2

print(f"your first number is = {num1} \nyour secound number is = {num2} \nresult = {result}")
# Out:
# Thank you for using my app
# please enter a number:  10
# please enter another number:  20
# your first number is = 10.0
# your secound number is = 20.0
# result = 30.0
