# %% [markdown]
# print("Hello World")

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Shift + Enter")
# Out:
# Shift + Enter

# %%
print("Hello Inception Army")
# Out:
# Hello Inception Army

# %%
print("Hello Programmer")
# Out:
# Hello Programmer

# %%
# this is a print Funcation
print("Inception Army")
# Out:
# Inception Army

# %%
# this print working for sum bewin two numbers
print(10+10)
# Out:
# 20
